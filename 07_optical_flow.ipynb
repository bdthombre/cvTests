# %% [markdown]
# Based on these video series
# https://www.youtube.com/watch?v=ZXY_njUyM_Q

# %%
import cv2
import scipy
import numpy as np
import scipy.signal
import matplotlib.pyplot as plt

# %%
file = "tests/paul_mcarty.mp4"
cap = cv2.VideoCapture(file)

# %%
start_frame = 201
diff_frame = 3

# %%
cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
ret, frame1 = cap.read()


cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame+diff_frame)
ret, frame2 = cap.read()

# %%
fig, (ax1, ax2)= plt.subplots(1,2)
ax1.imshow(frame1)
ax2.imshow(frame2)

# %%
frame1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
frame2 = cv2.cvtColor(frame2, cv2.COLOR_BGR2GRAY)

# %%
combined = cv2.absdiff(frame1, frame2)
_, threshold = cv2.threshold(combined, 25,255, cv2.THRESH_BINARY)
plt.imshow(combined, cmap='gray')

# %%
plt.imshow(threshold, cmap='gray')
